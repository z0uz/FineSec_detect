# %% [markdown]
# # 🚀 DeepSeek Vulnerability Detection Training
#
# Fine-tune DeepSeek Coder 1.3B on CVE + Synthetic vulnerability datasets
#
# **Requirements:**
# - Google Colab with GPU (T4 or better)
# - Runtime: GPU (Runtime > Change runtime type > GPU)
#
# **Training Time:**
# - 10k samples: ~1-2 hours on T4
# - Full dataset (115k): ~10-15 hours on T4

# %% [markdown]
# ## 1️⃣ Setup Environment

# %%
# Check GPU availability
# !nvidia-smi

# %%
# Install required packages
# !pip install -q transformers>=4.35.0 peft>=0.7.0 bitsandbytes>=0.41.0 accelerate>=0.25.0 datasets>=2.14.0 pyarrow>=14.0.0
